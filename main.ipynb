# %% [markdown]
# # SQL-challenge: Pewlett Hackard Data Review

# %%
# Import dependencies
from sqlalchemy import create_engine
import pandas as pd
import matplotlib.pyplot as plt

from config import pg_uri

# %% [markdown]
# ## Importing SQL Tables using SQLAlchemy and Pandas

# %%
# create database link 
engine = create_engine(pg_uri)

# %%
# Import employee salary data
employee_salary = pd.read_sql_table('employee_salaries',con=engine)

# %%
# Import average salary for each job title
average_salary = pd.read_sql_table('average_salary',con=engine)

# %% [markdown]
# ## Data Visualization

# %%
# Plot histogram of all employee salaries
employee_salary['salary'].plot.hist(bins=10, figsize = (12,8))

#Improve the format of the output
plt.title("Pewlett Hackard Salary Distribution for All Employees", fontsize = 18)
plt.xlabel('Salary Range ($)', fontsize =14)
plt.ylabel('Number of Employees', fontsize =14)
plt.xticks(fontsize = 12)
plt.yticks(fontsize = 12)

# Save the plot as an image file
plt.savefig('Images\Salary_Histogram')

# %%
# Plot average salary for each job title
average_salary.sort_values('round',ascending = False).plot.bar(figsize=(12,8), legend = False)

# Improve the format of the output
plt.title("Pewlett Hackard, Average Employee Salary", fontsize =18)
plt.xticks(ticks = [0,1,2,3,4,5,6], labels=average_salary['title'],rotation = '45')
plt.ylabel('Salary ($)', fontsize =14)
plt.xticks(fontsize = 12)
plt.yticks(fontsize = 12)

# Save the plot as an image file
plt.savefig('Images\Salary_Barchart')
